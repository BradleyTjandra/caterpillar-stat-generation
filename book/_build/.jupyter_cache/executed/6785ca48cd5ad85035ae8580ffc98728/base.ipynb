# %%
# Set up link to python code
import sys
sys.path.append("../src/")

# %%
# Set up report tablesj
import ReportTables
from importlib import reload
reload(ReportTables)
report_tables = ReportTables.ReportTables()

# %%
report_tables.show_stats_distribution()
